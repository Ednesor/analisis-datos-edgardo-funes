# %%
producto = {
 "id_articulo": 1054,
 "nombre": "Monitor 24 pulgadas",
 "precio": 150000,
 "stock": 15
}

# %%
producto["stock"] -= 1
producto["categoria"] = "Tecnologia"
print(f"Se vendió {producto["nombre"]}. Quedan {producto["stock"]} en stock.")
# Out:
# Se vendió Monitor 24 pulgadas. Quedan 12 en stock.
