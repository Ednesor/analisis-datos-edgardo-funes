# %% [markdown]
# # Edgardo Funes
# ## Mis habilidades
# * React
# * Typescript
# * PostgreSQL
#
# [Github](https://github.com/Ednesor)
#
# [LinkedIn](https://www.linkedin.com/in/edgardofunes/)
#
# [Portfolio](https://edgardofunes.com)
#
# Me considero una persona **proactiva**, con ganas de aprender y crecer profesionalmente. Me gusta trabajar en equipo y compartir conocimientos con mis compañeros. Estoy siempre dispuesto a enfrentar **nuevos desafíos** y a adaptarme a diferentes entornos de trabajo.
